# %%
import numpy as np
import pandas as pd

'''
def apply_binary(df, guidelines):
    df = df.copy()  # לא לשנות את המקור
    mapping = {"yes": 1, "no": 0}
    try: 
        for category in guidelines["Variable"]:
            try:
               df[category] 
            except:
                 raise IndexError('database and guideline not aligned')
        
            if guidelines["type"] == "binary":
                df[category] = 


                
            elif rules["type"] == "numeric":
                healthy_range = rules.get("healthy_range") #avoids key error if healthy_range ia not defiend.
                if isinstance(healthy_range, (list, tuple)) and len(healthy_range) >= 2:
                   df[category] = df[category].between(healthy_range[0], healthy_range[1]).astype(int)

            else:
                raise ValueError(f"Category '{category}' is numeric but healthy_range is not a list: {healthy_range}")
            
            return df[list(config.keys())]

    except:
        raise ImportError('add exception')

            
    '''

data = pd.read_csv("enhanced_anxiety_dataset.csv")
guidelines = pd.read_excel("health_guidelines.xlsx")

print(guidelines)
print(data)
# Out:
#                              Category                           Variable  \
# 0                   Lifestyle Factors       Physical Activity (hrs/week)
# 1                   Lifestyle Factors                        Sleep Hours
# 2                   Lifestyle Factors  Alcohol Consumption (drinks/week)
# 3                   Lifestyle Factors                Diet Quality (1-10)
# 4                   Lifestyle Factors           Caffeine Intake (mg/day)
# 5                   Lifestyle Factors                            Smoking
# 6   Health & Physiological Indicators                   Heart Rate (bpm)
# 7   Health & Physiological Indicators       Breathing Rate (breaths/min)
# 8   Health & Physiological Indicators                Stress Level (1-10)
# 9   Health & Physiological Indicators               Sweating Level (1-5)
# 10  Health & Physiological Indicators                          Dizziness
# 11              Mental Health History          Family History of Anxiety
# 12              Mental Health History       Therapy Sessions (per month)
# 13              Mental Health History            Recent Major Life Event
#
#        Type   Min    Max Condition
# 0   numeric   2.5    5.0       NaN
# 1   numeric   7.0    8.0       NaN
# 2   numeric   0.0    2.0       NaN
# 3   numeric   5.0   10.0       NaN
# 4   numeric   0.0  400.0       NaN
# 5    binary   NaN    NaN        No
# 6   numeric  60.0  100.0       NaN
# 7   numeric  10.0   20.0       NaN
# 8   numeric   1.0    3.0       NaN
# 9   numeric   1.0    2.0       NaN
# 10   binary   NaN    NaN        No
# 11   binary   NaN    NaN        No
# 12  numeric   1.0   12.0       NaN
# 13   binary   NaN    NaN        No
#        Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0       29  Female     Artist          6.0                           2.7
# 1       46   Other      Nurse          6.2                           5.7
# 2       64    Male      Other          5.0                           3.7
# 3       20  Female  Scientist          5.8                           2.8
# 4       49  Female      Other          8.2                           2.3
# ...    ...     ...        ...          ...                           ...
# 10995   23  Female   Engineer          6.1                           3.1
# 10996   50   Other    Teacher          6.6                           3.6
# 10997   29    Male      Nurse          6.7                           6.9
# 10998   53   Other     Artist          5.7                           2.7
# 10999   56   Other    Teacher          6.1                           1.1
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                           181                                 10     Yes
# 1                           200                                  8     Yes
# 2                           117                                  4      No
# 3                           360                                  6     Yes
# 4                           247                                  4     Yes
# ...                         ...                                ...     ...
# 10995                       566                                  9     Yes
# 10996                        64                                 17     Yes
# 10997                       159                                 14      No
# 10998                       248                                  8      No
# 10999                       205                                 11      No
#
#       Family History of Anxiety  Stress Level (1-10)  Heart Rate (bpm)  \
# 0                            No                   10               114
# 1                           Yes                    1                62
# 2                           Yes                    1                91
# 3                            No                    4                86
# 4                            No                    1                98
# ...                         ...                  ...               ...
# 10995                        No                    8                91
# 10996                        No                    7                95
# 10997                        No                    8                72
# 10998                        No                    4               112
# 10999                        No                    1                66
#
#        Breathing Rate (breaths/min)  Sweating Level (1-5) Dizziness  \
# 0                                14                     4        No
# 1                                23                     2       Yes
# 2                                28                     3        No
# 3                                17                     3        No
# 4                                19                     4       Yes
# ...                             ...                   ...       ...
# 10995                            28                     1       Yes
# 10996                            17                     3        No
# 10997                            16                     1       Yes
# 10998                            28                     3       Yes
# 10999                            13                     3        No
#
#       Medication  Therapy Sessions (per month) Recent Major Life Event  \
# 0            Yes                             3                     Yes
# 1             No                             2                      No
# 2             No                             1                     Yes
# 3             No                             0                      No
# 4            Yes                             1                      No
# ...          ...                           ...                     ...
# 10995        Yes                             1                      No
# 10996         No                             2                      No
# 10997        Yes                             2                     Yes
# 10998        Yes                             1                     Yes
# 10999         No                             2                     Yes
#
#        Diet Quality (1-10)  Anxiety Level (1-10)
# 0                        7                   5.0
# 1                        8                   3.0
# 2                        1                   1.0
# 3                        1                   2.0
# 4                        3                   1.0
# ...                    ...                   ...
# 10995                    3                   6.0
# 10996                    7                   3.0
# 10997                    7                   4.0
# 10998                    2                   4.0
# 10999                    8                   2.0
#
# [11000 rows x 19 columns]
